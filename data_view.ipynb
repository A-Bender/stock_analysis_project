# %%
import pandas as pd

df = pd.read_csv("screener_stocks_68.csv")

# %%
df
# Out:
#    Symbol                 Company Name     Market Cap  Stock Price % Change  \
# 0   BRK.A      Berkshire Hathaway Inc.  1017492275200    703300.00   -0.09%
# 1   BRK.B      Berkshire Hathaway Inc.  1011022495744       468.83   -0.01%
# 2    AAPL                   Apple Inc.  3454262616000       229.00    0.32%
# 3    MSFT        Microsoft Corporation  3069638905600       415.49   -0.55%
# 4    GOOG                Alphabet Inc.  2062036564433       177.33   -1.25%
# ..    ...                          ...            ...          ...      ...
# 63    ELV        Elevance Health, Inc.    93604122800       397.48    0.83%
# 64    PGR  The Progressive Corporation   154326313280       257.02    0.99%
# 65    HCA         HCA Healthcare, Inc.    84155395280       333.00   -0.63%
# 66    LOW       Lowe's Companies, Inc.   150457714680       263.03    1.45%
# 67   QCOM        QUALCOMM Incorporated   172716060000       154.27   -6.34%
#
# ...
